# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, BatchNormalization,Dropout,GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.applications import EfficientNetB0

import numpy as np
from glob import glob

# %%
batch = 32
img_height = 180
img_width = 180

train_path = 'C:/Users/athul/Downloads/IP J comp/Train'
test_path = 'C:/Users/athul/Downloads/IP J comp/Test'

# %%
import PIL, pathlib
train_path = pathlib.Path(train_path)
onehundred = list(train_path.glob('1Hundrednote/*'))
PIL.Image.open(str(onehundred[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x152>

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
                train_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch)
print(train_ds)
# Out:
# Found 153 files belonging to 7 classes.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
#  validation_split=0.1,
 # subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch)
# Out:
# Found 42 files belonging to 7 classes.

# %%
class_names = train_ds.class_names
print(train_ds)
print(class_names)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# ['1Hundrednote', '2Hundrednote', '2Thousandnote', '5Hundrednote', 'Fiftynote', 'Tennote', 'Twentynote']

# %%
#Data Visualization

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#normalize data by using a rescaling layer

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0072503127 1.0

# %%
Classifier=Sequential()

Classifier.add(layers.experimental.preprocessing.Rescaling(1./255,
      input_shape=(img_height, img_width, 3)))

Classifier.add(Conv2D(32,(3,3),
                      input_shape=(img_height,img_width,3), 
                      activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

# %%
Classifier.compile(
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)

# %%
Classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 59168)             0
#
#  dense (Dense)               (None, 128)               7573632
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,584,679
# Trainable params: 7,584,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
from PIL import _imaging
from PIL import Image
#fit the classifier
epochs = 30
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/30
# C:\Users\athul\AppData\Roaming\Python\Python310\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 5/5 [==============================] - 4s 708ms/step - loss: 7.0720 - accuracy: 0.0915 - val_loss: 2.8197 - val_accuracy: 0.1429
# Epoch 2/30
# 5/5 [==============================] - 3s 572ms/step - loss: 2.2486 - accuracy: 0.1765 - val_loss: 1.9312 - val_accuracy: 0.1667
# Epoch 3/30
# 5/5 [==============================] - 3s 550ms/step - loss: 1.7658 - accuracy: 0.4183 - val_loss: 1.7770 - val_accuracy: 0.1905
# Epoch 4/30
# 5/5 [==============================] - 3s 529ms/step - loss: 1.3708 - accuracy: 0.4967 - val_loss: 1.5991 - val_accuracy: 0.4762
# Epoch 5/30
# 5/5 [==============================] - 3s 508ms/step - loss: 1.0603 - accuracy: 0.6601 - val_loss: 1.3908 - val_accuracy: 0.5238
# Epoch 6/30
# 5/5 [==============================] - 3s 509ms/step - loss: 0.5924 - accuracy: 0.8954 - val_loss: 1.1509 - val_accuracy: 0.5952
# Epoch 7/30
# 5/5 [==============================] - 3s 529ms/step - loss: 0.4083 - accuracy: 0.9216 - val_loss: 1.4561 - val_accuracy: 0.5952
# Epoch 8/30
# 5/5 [==============================] - 2s 497ms/step - loss: 0.2661 - accuracy: 0.9477 - val_loss: 1.1394 - val_accuracy: 0.5952
# Epoch 9/30
# 5/5 [==============================] - 2s 510ms/step - loss: 0.1457 - accuracy: 0.9608 - val_loss: 1.1920 - val_accuracy: 0.6190
# Epoch 10/30
# 5/5 [==============================] - 2s 490ms/step - loss: 0.0607 - accuracy: 0.9935 - val_loss: 1.3052 - val_accuracy: 0.5714
# Epoch 11/30
# 5/5 [==============================] - 2s 481ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 1.6453 - val_accuracy: 0.5238
# Epoch 12/30
# 5/5 [==============================] - 2s 495ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.4736 - val_accuracy: 0.5714
# Epoch 13/30
# 5/5 [==============================] - 3s 527ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.4980 - val_accuracy: 0.5714
# Epoch 14/30
# 5/5 [==============================] - 2s 509ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.4705 - val_accuracy: 0.6190
# Epoch 15/30
# 5/5 [==============================] - 2s 496ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.4220 - val_accuracy: 0.6429
# Epoch 16/30
# 5/5 [==============================] - 3s 523ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4334 - val_accuracy: 0.5952
# Epoch 17/30
# 5/5 [==============================] - 3s 525ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5136 - val_accuracy: 0.6190
# Epoch 18/30
# 5/5 [==============================] - 3s 557ms/step - loss: 8.5073e-04 - accuracy: 1.0000 - val_loss: 1.6415 - val_accuracy: 0.5952
# Epoch 19/30
# 5/5 [==============================] - 3s 520ms/step - loss: 7.5224e-04 - accuracy: 1.0000 - val_loss: 1.6556 - val_accuracy: 0.5952
# Epoch 20/30
# 5/5 [==============================] - 3s 541ms/step - loss: 5.9084e-04 - accuracy: 1.0000 - val_loss: 1.6495 - val_accuracy: 0.6429
# Epoch 21/30
# 5/5 [==============================] - 3s 522ms/step - loss: 5.4289e-04 - accuracy: 1.0000 - val_loss: 1.6327 - val_accuracy: 0.6429
# Epoch 22/30
# 5/5 [==============================] - 2s 487ms/step - loss: 4.7016e-04 - accuracy: 1.0000 - val_loss: 1.6005 - val_accuracy: 0.6429
# Epoch 23/30
# 5/5 [==============================] - 2s 483ms/step - loss: 4.1954e-04 - accuracy: 1.0000 - val_loss: 1.5916 - val_accuracy: 0.6429
# Epoch 24/30
# 5/5 [==============================] - 2s 498ms/step - loss: 3.9196e-04 - accuracy: 1.0000 - val_loss: 1.6080 - val_accuracy: 0.6190
# Epoch 25/30
# 5/5 [==============================] - 3s 527ms/step - loss: 3.6906e-04 - accuracy: 1.0000 - val_loss: 1.6200 - val_accuracy: 0.6190
# Epoch 26/30
# 5/5 [==============================] - 2s 471ms/step - loss: 3.4242e-04 - accuracy: 1.0000 - val_loss: 1.6227 - val_accuracy: 0.6429
# Epoch 27/30
# 5/5 [==============================] - 2s 465ms/step - loss: 3.2495e-04 - accuracy: 1.0000 - val_loss: 1.6316 - val_accuracy: 0.6190
# Epoch 28/30
# 5/5 [==============================] - 2s 466ms/step - loss: 3.0599e-04 - accuracy: 1.0000 - val_loss: 1.6403 - val_accuracy: 0.6190
# Epoch 29/30
# 5/5 [==============================] - 2s 480ms/step - loss: 2.8991e-04 - accuracy: 1.0000 - val_loss: 1.6544 - val_accuracy: 0.6190
# Epoch 30/30
# 5/5 [==============================] - 2s 477ms/step - loss: 2.7716e-04 - accuracy: 1.0000 - val_loss: 1.6624 - val_accuracy: 0.5952

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
# Out:
# mean_test_accuracy:  0.557142865161101

# %%
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_train_accuracy:  0.8854030517240365

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
#Data Augmentation to reduce overfitting

data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
Classifier=Sequential()

Classifier.add(data_augmentation)
Classifier.add(layers.experimental.preprocessing.Rescaling(1./255,
      input_shape=(img_height, img_width, 3)))

Classifier.add(Conv2D(32,(3,3),
                      input_shape=(img_height,img_width,3), 
                      activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))
Classifier.add(layers.Dropout(0.2))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
Classifier.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
Classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 43, 43, 32)        0
#
#  flatten_1 (Flatten)         (None, 59168)             0
#
#  dense_2 (Dense)             (None, 128)               7573632
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,584,679
# Trainable params: 7,584,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 30
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 5/5 [==============================] - 6s 540ms/step - loss: 3.8862 - accuracy: 0.0719 - val_loss: 2.2269 - val_accuracy: 0.1429
# Epoch 2/30
# 5/5 [==============================] - 3s 587ms/step - loss: 2.0094 - accuracy: 0.1307 - val_loss: 1.9386 - val_accuracy: 0.1429
# Epoch 3/30
# 5/5 [==============================] - 3s 604ms/step - loss: 1.9312 - accuracy: 0.1373 - val_loss: 1.8998 - val_accuracy: 0.2143
# Epoch 4/30
# 5/5 [==============================] - 3s 573ms/step - loss: 1.8750 - accuracy: 0.1699 - val_loss: 1.8308 - val_accuracy: 0.3333
# Epoch 5/30
# 5/5 [==============================] - 3s 536ms/step - loss: 1.7827 - accuracy: 0.3072 - val_loss: 1.7262 - val_accuracy: 0.3333
# Epoch 6/30
# 5/5 [==============================] - 4s 758ms/step - loss: 1.6904 - accuracy: 0.3529 - val_loss: 1.4931 - val_accuracy: 0.3810
# Epoch 7/30
# 5/5 [==============================] - 3s 587ms/step - loss: 1.5362 - accuracy: 0.4314 - val_loss: 1.2822 - val_accuracy: 0.5238
# Epoch 8/30
# 5/5 [==============================] - 3s 670ms/step - loss: 1.2894 - accuracy: 0.5163 - val_loss: 1.1728 - val_accuracy: 0.5476
# Epoch 9/30
# 5/5 [==============================] - 3s 520ms/step - loss: 1.0632 - accuracy: 0.6013 - val_loss: 1.5858 - val_accuracy: 0.3810
# Epoch 10/30
# 5/5 [==============================] - 3s 518ms/step - loss: 0.9457 - accuracy: 0.6144 - val_loss: 1.4205 - val_accuracy: 0.4048
# Epoch 11/30
# 5/5 [==============================] - 3s 567ms/step - loss: 0.8595 - accuracy: 0.7255 - val_loss: 1.1860 - val_accuracy: 0.5000
# Epoch 12/30
# 5/5 [==============================] - 3s 556ms/step - loss: 0.8719 - accuracy: 0.6732 - val_loss: 1.4408 - val_accuracy: 0.5238
# Epoch 13/30
# 5/5 [==============================] - 3s 546ms/step - loss: 0.8353 - accuracy: 0.7255 - val_loss: 1.4573 - val_accuracy: 0.4762
# Epoch 14/30
# 5/5 [==============================] - 3s 529ms/step - loss: 0.5995 - accuracy: 0.8693 - val_loss: 1.2754 - val_accuracy: 0.5952
# Epoch 15/30
# 5/5 [==============================] - 3s 524ms/step - loss: 0.4755 - accuracy: 0.8497 - val_loss: 1.0400 - val_accuracy: 0.7143
# Epoch 16/30
# 5/5 [==============================] - 2s 488ms/step - loss: 0.3807 - accuracy: 0.8758 - val_loss: 1.6860 - val_accuracy: 0.5476
# Epoch 17/30
# 5/5 [==============================] - 2s 498ms/step - loss: 0.3283 - accuracy: 0.8758 - val_loss: 1.1343 - val_accuracy: 0.6429
# Epoch 18/30
# 5/5 [==============================] - 3s 530ms/step - loss: 0.2319 - accuracy: 0.9216 - val_loss: 1.3558 - val_accuracy: 0.6429
# Epoch 19/30
# 5/5 [==============================] - 2s 489ms/step - loss: 0.3601 - accuracy: 0.8758 - val_loss: 1.7927 - val_accuracy: 0.4762
# Epoch 20/30
# 5/5 [==============================] - 3s 532ms/step - loss: 0.3222 - accuracy: 0.8824 - val_loss: 1.1910 - val_accuracy: 0.6190
# Epoch 21/30
# 5/5 [==============================] - 2s 491ms/step - loss: 0.2974 - accuracy: 0.9150 - val_loss: 2.1040 - val_accuracy: 0.6429
# Epoch 22/30
# 5/5 [==============================] - 2s 492ms/step - loss: 0.2262 - accuracy: 0.9346 - val_loss: 1.5912 - val_accuracy: 0.5952
# Epoch 23/30
# 5/5 [==============================] - 2s 490ms/step - loss: 0.2413 - accuracy: 0.9085 - val_loss: 2.3843 - val_accuracy: 0.5952
# Epoch 24/30
# 5/5 [==============================] - 2s 493ms/step - loss: 0.2789 - accuracy: 0.9020 - val_loss: 1.1233 - val_accuracy: 0.7381
# Epoch 25/30
# 5/5 [==============================] - 2s 524ms/step - loss: 0.2344 - accuracy: 0.9346 - val_loss: 1.3353 - val_accuracy: 0.6429
# Epoch 26/30
# 5/5 [==============================] - 2s 486ms/step - loss: 0.1784 - accuracy: 0.9477 - val_loss: 1.1074 - val_accuracy: 0.6905
# Epoch 27/30
# 5/5 [==============================] - 2s 489ms/step - loss: 0.1522 - accuracy: 0.9542 - val_loss: 1.5832 - val_accuracy: 0.6429
# Epoch 28/30
# 5/5 [==============================] - 3s 539ms/step - loss: 0.1065 - accuracy: 0.9739 - val_loss: 1.6041 - val_accuracy: 0.6190
# Epoch 29/30
# 5/5 [==============================] - 3s 524ms/step - loss: 0.0733 - accuracy: 0.9935 - val_loss: 1.9359 - val_accuracy: 0.6190
# Epoch 30/30
# 5/5 [==============================] - 3s 545ms/step - loss: 0.1059 - accuracy: 0.9739 - val_loss: 0.8288 - val_accuracy: 0.7619

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
print('\n')
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_test_accuracy:  0.5230158771077792
#
#
# mean_train_accuracy:  0.7015250630676746

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(180,180,3))

Classifier=Sequential()

Classifier.add(effnet)

Classifier.add(GlobalAveragePooling2D())

Classifier.add(Flatten())

Classifier.add(Dense(512,activation='relu'))
Classifier.add(Dense(128,activation='relu'))

Classifier.add(Dense(64,activation='relu'))
Classifier.add(Dense(32,activation='relu'))

Classifier.add(Dropout(0.5))

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

# %%
Classifier.compile(
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)

# %%
Classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 6, 6, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten_2 (Flatten)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 512)               655872
#
#  dense_5 (Dense)             (None, 128)               65664
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 128)               4224
#
#  dense_9 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 4,786,570
# Trainable params: 4,744,547
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
from PIL import _imaging
from PIL import Image
#fit the classifier
epochs = 30
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/30
# 5/5 [==============================] - 18s 4s/step - loss: 1.9327 - accuracy: 0.1634 - val_loss: 1.9092 - val_accuracy: 0.3095
# Epoch 2/30
# 5/5 [==============================] - 16s 3s/step - loss: 1.8345 - accuracy: 0.2484 - val_loss: 1.8474 - val_accuracy: 0.3571
# Epoch 3/30
# 5/5 [==============================] - 17s 4s/step - loss: 1.6647 - accuracy: 0.3595 - val_loss: 1.7681 - val_accuracy: 0.3095
# Epoch 4/30
# 5/5 [==============================] - 16s 3s/step - loss: 1.4449 - accuracy: 0.3987 - val_loss: 1.6112 - val_accuracy: 0.3810
# Epoch 5/30
# 5/5 [==============================] - 16s 3s/step - loss: 1.2831 - accuracy: 0.5490 - val_loss: 1.4819 - val_accuracy: 0.4048
# Epoch 6/30
# 5/5 [==============================] - 16s 3s/step - loss: 1.1109 - accuracy: 0.6340 - val_loss: 1.3935 - val_accuracy: 0.5000
# Epoch 7/30
# 5/5 [==============================] - 19s 4s/step - loss: 0.8280 - accuracy: 0.6928 - val_loss: 1.2842 - val_accuracy: 0.5714
# Epoch 8/30
# 5/5 [==============================] - 19s 4s/step - loss: 0.6767 - accuracy: 0.8105 - val_loss: 1.3777 - val_accuracy: 0.7381
# Epoch 9/30
# 5/5 [==============================] - 18s 4s/step - loss: 0.5021 - accuracy: 0.8497 - val_loss: 1.5886 - val_accuracy: 0.7619
# Epoch 10/30
# 5/5 [==============================] - 17s 3s/step - loss: 0.4038 - accuracy: 0.8497 - val_loss: 1.5889 - val_accuracy: 0.8095
# Epoch 11/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.3228 - accuracy: 0.8824 - val_loss: 0.9701 - val_accuracy: 0.8095
# Epoch 12/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.2029 - accuracy: 0.9346 - val_loss: 0.4394 - val_accuracy: 0.9286
# Epoch 13/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.2254 - accuracy: 0.9477 - val_loss: 0.6589 - val_accuracy: 0.9048
# Epoch 14/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.2054 - accuracy: 0.9477 - val_loss: 0.4938 - val_accuracy: 0.9524
# Epoch 15/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.1157 - accuracy: 0.9739 - val_loss: 0.1202 - val_accuracy: 0.9286
# Epoch 16/30
# 5/5 [==============================] - 15s 3s/step - loss: 0.1997 - accuracy: 0.9412 - val_loss: 0.2101 - val_accuracy: 0.9762
# Epoch 17/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.2088 - accuracy: 0.9346 - val_loss: 0.7553 - val_accuracy: 0.8810
# Epoch 18/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.3342 - accuracy: 0.9216 - val_loss: 1.4494 - val_accuracy: 0.8095
# Epoch 19/30
# 5/5 [==============================] - 15s 3s/step - loss: 0.2767 - accuracy: 0.9216 - val_loss: 1.0198 - val_accuracy: 0.8333
# Epoch 20/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.4216 - accuracy: 0.8758 - val_loss: 2.3670 - val_accuracy: 0.7619
# Epoch 21/30
# 5/5 [==============================] - 17s 3s/step - loss: 0.6195 - accuracy: 0.8693 - val_loss: 4.3504 - val_accuracy: 0.6667
# Epoch 22/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.5272 - accuracy: 0.8431 - val_loss: 5.0044 - val_accuracy: 0.6667
# Epoch 23/30
# 5/5 [==============================] - 15s 3s/step - loss: 0.5219 - accuracy: 0.8170 - val_loss: 4.0879 - val_accuracy: 0.6667
# Epoch 24/30
# 5/5 [==============================] - 18s 4s/step - loss: 0.3980 - accuracy: 0.8693 - val_loss: 3.6648 - val_accuracy: 0.6905
# Epoch 25/30
# 5/5 [==============================] - 18s 4s/step - loss: 0.2314 - accuracy: 0.9216 - val_loss: 5.0562 - val_accuracy: 0.7143
# Epoch 26/30
# 5/5 [==============================] - 18s 4s/step - loss: 0.1196 - accuracy: 0.9673 - val_loss: 5.4098 - val_accuracy: 0.6905
# Epoch 27/30
# 5/5 [==============================] - 17s 3s/step - loss: 0.0995 - accuracy: 0.9673 - val_loss: 4.6433 - val_accuracy: 0.7381
# Epoch 28/30
# 5/5 [==============================] - 16s 3s/step - loss: 0.1763 - accuracy: 0.9542 - val_loss: 4.0296 - val_accuracy: 0.7381
# Epoch 29/30
# 5/5 [==============================] - 15s 3s/step - loss: 0.1217 - accuracy: 0.9542 - val_loss: 4.5370 - val_accuracy: 0.7857
# Epoch 30/30
# 5/5 [==============================] - 15s 3s/step - loss: 0.1594 - accuracy: 0.9216 - val_loss: 4.0320 - val_accuracy: 0.8333

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
# Out:
# mean_test_accuracy:  0.7039682537317276

# %%
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_train_accuracy:  0.797385628024737

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
#Use classifier to run prediction on any new image

from tensorflow.keras.preprocessing import image
img = image.load_img('C:/Users/athul/Downloads/IP J comp/PI/2.jpg',
                       target_size=(img_height,img_width))
img
# Out:
# <PIL.Image.Image image mode=RGB size=180x180>

# %%
test_image=image.img_to_array(img)
test_image=np.expand_dims(test_image, axis = 0)

result =np.argmax(Classifier.predict(test_image), axis=1)
result
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([6], dtype=int64)

# %%
prediction = class_names[result[0]]
prediction
# Out:
# 'Twentynote'
